# %%
# Import libraries 
import sqlite3
import pandas as pd

# %%
# load sql server into jupyter
# %load_ext sql

# %%
# connect to database
cnn = sqlite3.connect('yusri.db')

# %%
# choose database
# %sql sqlite:///yusri.db

# %%
# Add dataset into database using pandas
# Dataset and database must in the same directory
ChicagoCrimeData = pd.read_csv("C:\\Users\\User PC\\Desktop\\ChicagoCrimeData.csv")
ChicagoPublicSchools = pd.read_csv("C:\\Users\\User PC\\Desktop\\ChicagoPublicSchools.csv")
ChicagoCensusData = pd.read_csv("C:\\Users\\User PC\\Desktop\\ChicagoCensusData.csv")

ChicagoCrimeData.to_sql('ChicagoCrimeData',cnn)
ChicagoPublicSchools.to_sql('ChicagoPublicSchools',cnn)
ChicagoCensusData.to_sql('ChicagoCensusData',cnn)

# pandas_name.to_sql('dataset_name,cnn')
# Out:
# C:\Users\User PC\miniconda3\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
# view dataset in database
# %sql SELECT sql FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///yusri.db
# Done.
# [('CREATE TABLE "ChicagoCrimeData" (\n"index" INTEGER,\n  "ID" INTEGER,\n  "CASE_NUMBER" TEXT,\n  "DATE" TEXT,\n  "BLOCK" TEXT,\n  "IUCR" TEXT,\n  "PRIM ... (205 characters truncated) ... \n  "FBICODE" TEXT,\n  "X_COORDINATE" REAL,\n  "Y_COORDINATE" REAL,\n  "YEAR" INTEGER,\n  "LATITUDE" REAL,\n  "LONGITUDE" REAL,\n  "LOCATION" TEXT\n)',),
#  ('CREATE TABLE "ChicagoPublicSchools" (\n"index" INTEGER,\n  "School_ID" INTEGER,\n  "NAME_OF_SCHOOL" TEXT,\n  "Elementary, Middle, or High School" TEX ... (2235 characters truncated) ... tude" REAL,\n  "COMMUNITY_AREA_NUMBER" INTEGER,\n  "COMMUNITY_AREA_NAME" TEXT,\n  "Ward" INTEGER,\n  "Police_District" INTEGER,\n  "Location" TEXT\n)',),
# ...

# %%
# Remove dataset in database
#%sql DROP TABLE ChicagoCrimeData

# %% [markdown]
# # Analysis

# %%
# %%sql
# SELECT * FROM ChicagoCrimeData
# Out:
#  * sqlite:///yusri.db
# Done.
# [(0, 3512276, 'HK587712', '28/8/2004', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 0, 0, 911, 9, 14.0, 58.0, '6', 1155838.0, 1873050.0, 2004, 41.8074405, -87.70395585, '(41.8074405, -87.703955849)'),
#  (1, 3406613, 'HK456306', '26/6/2004', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 0, 0, 1112, 11, 27.0, 23.0, '6', 1152206.0, 1906127.0, 2004, 41.89827996, -87.71640551, '(41.898279962, -87.716405505)'),
#  (2, 8002131, 'HT233595', '4/4/2011', '043XX S WABASH AVE', '820', 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 0, 0, 221, 2, 3.0, 38.0, '6', 1177436.0, 1876313.0, 2011, 41.81593313, -87.62464213, '(41.815933131, -87.624642127)'),
#  (3, 7903289, 'HT133522', '30/12/2010', '083XX S KINGSTON AVE', '840', 'THEFT', 'FINANCIAL ID THEFT: OVER $300', 'RESIDENCE', 0, 0, 423, 4, 7.0, 46.0, '6', 1194622.0, 1850125.0, 2010, 41.74366532, -87.56246276, '(41.743665322, -87.562462756)'),
# ...

# %%
# %%sql
# SELECT * FROM ChicagoPublicSchools
# Out:
#  * sqlite:///yusri.db
# Done.
# [(0, 610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Weak', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %%
# %%sql
# SELECT * FROM ChicagoCensusData
# Out:
#  * sqlite:///yusri.db
# Done.
# [(0, 1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (1, 2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (2, 3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (3, 4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (4, 5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0),
#  (5, 6.0, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17.0, 60058, 5.0),
#  (6, 7.0, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2.0),
#  (7, 8.0, 'Near North Side', 1.9, 12.9, 7.0, 2.5, 22.6, 88669, 1.0),
#  (8, 9.0, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8.0),
#  (9, 10.0, 'Norwood Park', 2.0, 5.4, 9.0, 11.5, 39.5, 32875, 21.0),
#  (10, 11.0, 'Jefferson Park', 2.7, 8.6, 12.4, 13.4, 35.5, 27751, 25.0),
#  (11, 12.0, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11.0),
#  (12, 13.0, 'North Park', 3.9, 13.2, 9.9, 14.4, 39.0, 26576, 33.0),
#  (13, 14.0, 'Albany Park', 11.3, 19.2, 10.0, 32.9, 32.0, 21323, 53.0),
# ...

# %% [markdown]
# 1. Find the total number of crimes recorded in the CRIME table.

# %%
# %%sql
# SELECT
#     count(*) as Total_Crime
# FROM
#     ChicagoCrimeData
# Out:
#  * sqlite:///yusri.db
# Done.
# [(533,)]

# %% [markdown]
# 2. List community areas with per capita income less than 11000.

# %%
# %%sql
# SELECT
#     community_area_name
# FROM
#     ChicagoCensusData
# WHERE
#     per_capita_income < 11000
# Out:
#  * sqlite:///yusri.db
# Done.
# [('West Garfield Park',),
#  ('South Lawndale',),
#  ('Fuller Park',),
#  ('Riverdale',)]

# %% [markdown]
# 3. List all case numbers for crimes  involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %%sql
# SELECT
#     case_number
# FROM
#     chicagocrimedata
# WHERE
#     description LIKE '%minor%'
# Out:
#  * sqlite:///yusri.db
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# 4. List all kidnapping crimes involving a child?

# %%
# %%sql
# SELECT
#     *
# FROM
#     chicagocrimedata
# WHERE
#     primary_type = 'KIDNAPPING' AND description LIKE '%child%'
# Out:
#  * sqlite:///yusri.db
# Done.
# [(520, 5276766, 'HN144152', '26/1/2007', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %% [markdown]
# 5. What kind of crimes were recorded at schools?

# %%
# %%sql
# SELECT
#     distinct primary_type
# FROM
#     chicagocrimedata
# WHERE
#     location_description LIKE '%SCHOOL%'
# Out:
#  * sqlite:///yusri.db
# Done.
# [('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('NARCOTICS',),
#  ('ASSAULT',),
#  ('CRIMINAL TRESPASS',),
#  ('PUBLIC PEACE VIOLATION',)]

# %% [markdown]
# 6. List the average safety score for all types of schools.

# %%
# %%sql
# SELECT
#     [Elementary, Middle, or High School] AS TYPE_OF_SCHOOLS,
#     round(AVG(safety_score),6) AS AVERAGE_SAFETY_SCORE
# FROM
#     chicagopublicschools
# GROUP BY
#     [Elementary, Middle, or High School]
# Out:
#  * sqlite:///yusri.db
# Done.
# [('ES', 49.520384), ('HS', 49.623529), ('MS', 48.0)]

# %% [markdown]
# 7. List 5 community areas with highest % of households below poverty line.

# %%
# %%sql
# SELECT
#     community_area_name,percent_households_below_poverty
# FROM
#     ChicagoCensusData
# ORDER BY
#     percent_households_below_poverty DESC
# LIMIT 5
# Out:
#  * sqlite:///yusri.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# 8. Which community area(number) is most crime prone?

# %%
# %%sql
# SELECT
#     community_area_number
# FROM
#     ChicagoCrimeData
# GROUP BY
#     community_area_number
# ORDER BY
#     count(community_area_number) DESC
# LIMIT 1
# Out:
#  * sqlite:///yusri.db
# Done.
# [(25.0,)]

# %% [markdown]
# 9. Use a sub-query to find the name of the community area with highest hardship index.

# %%
# %%sql
# SELECT
#    community_area_name
# FROM
#     chicagocensusdata
# WHERE
#     hardship_index = (SELECT
#                           MAX(hardship_index)
#                       FROM
#                           chicagocensusdata)
# Out:
#  * sqlite:///yusri.db
# Done.
# [('Riverdale',)]

# %% [markdown]
# 10. Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %%sql
# SELECT
#    community_area_name
# FROM
#     chicagocensusdata
# WHERE
#     community_area_number = (SELECT
#                                  community_area_number
#                              FROM
#                                  chicagocrimedata
#                              GROUP BY
#                                  community_area_number
#                              ORDER BY
#                                  COUNT(community_area_number) DESC)
# LIMIT 1
# Out:
#  * sqlite:///yusri.db
# Done.
# [('Austin',)]
